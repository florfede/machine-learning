# %%
import csv
import datetime
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt 
from statsmodels.tsa.stattools import acf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import statsmodels.graphics.tsaplots as sgt

matplotlib.rcParams['figure.figsize']=[25,5] 

matplotlib.rcParams['figure.figsize']=[12.0,8.0] 
import warnings
warnings.filterwarnings('ignore')

# %%
url='https://raw.githubusercontent.com/florfede/machine-learning/main/royalties_dates.csv'
data = pd.read_csv(url)

# %%
data['dates'] = pd.to_datetime(data['dates'], format='%m/%d/%Y')

# %%
data.head(200)
# Out:
#             royalties  spotify_m_listeners  spotify_followers  \
# dates
# 2017-01-01  13.861532                    0                  0
# 2017-01-02  13.554865                    0                  0
# 2017-01-03  13.599099                    0                  0
# 2017-01-04  13.627826                    0                  0
# 2017-01-05  13.649904                    0                  0
# ...               ...                  ...                ...
# 2017-07-15  26.640614                    0                128
# 2017-07-16  26.644808                    0                128
# 2017-07-17  26.641705                    0                128
# 2017-07-18  26.644456                    0                128
# 2017-07-19  26.648933                    0                129
#
#             youtube_subscribers  youtube_views  instagram_followers  \
# dates
# 2017-01-01                    0              0                    0
# ...

# %%
# Histograms
matplotlib.rcParams['figure.figsize']=[12.0,8.0] 
sns.distplot(data.royalties,bins=20,color='#fcba03')
plt.title('Histograma de la Serie Royalties')
# Out:
# Text(0.5, 1.0, 'Histograma de la Serie Royalties')

# %% [markdown]
# #### Se adapta el dataset para trabajarlo segun sus series temporales

# %%
data.dates = pd.to_datetime(data.dates, dayfirst = True) 
data.set_index("dates", inplace=True)
data=data.asfreq('d')

# %%
# Serie Royalties
matplotlib.rcParams['figure.figsize']=[25,5] 

plt.plot(data.royalties, linewidth=1.5)
plt.title("evolucion simple de la serie royalties");
plot_acf(data.royalties,lags=20,title="grafico de autocorrelcion de la serie royalties")
plot_pacf(data.royalties,lags=20,title="grafico de autocorrelacion parcial de la serie royalties")
plt.show()
